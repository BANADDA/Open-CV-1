# %% [markdown]
# <a href="https://colab.research.google.com/github/BANADDA/Open-CV-1/blob/main/OpenCv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing required libraries
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
#Reading image 
img = cv2.imread("/lena.png", 8)
#Displaying image
cv2_imshow(img)
#Waiting for keystroke
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F61D822CE90>
# -1
